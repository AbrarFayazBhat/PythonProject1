# %% [markdown]
# MY DATA MY STORY

# %%
import openpyxl
import math

# %% [markdown]
# TECH PRODUCTIVITY INDEX

# %%
def calculate_TPI(filename,sheet_name,column,valid_days):
    wb=openpyxl.load_workbook(filename, read_only=True)
    ws=wb[sheet_name]
    values=[]
    for row in range(6,ws.max_row+1):
        value=ws.cell(row,column).value
        if value is not None:
            values.append(value)
    return math.fsum(values)/valid_days

# %% [markdown]
# ACADEMIC ACTIVITY INDEX

# %%
def calculate_AAI(filename,sheet_name,column,valid_days):
    wb=openpyxl.load_workbook(filename, read_only=True)
    ws=wb[sheet_name]
    values=[]
    for row in range(6,ws.max_row+1):
        value=ws.cell(row,column).value
        if value is not None:
            values.append(value)
    for row in range(6,ws.max_row+1):
        value=ws.cell()
    return math.fsum(values)/valid_days

# %%
tpi=calculate_TPI("12607000.xlsx","Daily Log",5,25)
print(f'Tech Productivity Index is: {tpi}')
# Out:
# Tech Productivity Index is: 186.4
